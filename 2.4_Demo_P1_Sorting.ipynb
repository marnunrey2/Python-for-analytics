# %% [markdown]
# # Demo 2.4 ***sort_values()***: Sorting a *pandas* Dataframe
#
#
# - **Demonstrates**:
#   - Sorting with  ***sort_values()***
#
#
# - **Sorting by One, Two or Three Columns**
#   - [**Sorting by a Single Column**](#Sorting-by-a-Single-Column)
#   - [**Sorting by Two Columns**](#Sorting-by-Two-Columns)
#   - [**Sorting by Three Columns**](#Sorting-by-Three-Columns)
#
#
# - Data file:  **Cars.csv**

# %%
import pandas as pd

# %% [markdown]
# ### Read the datafile File into a *pandas* Dataframe

# %%
df = pd.read_csv("Data/Cars.csv")

print(df.shape)
df.head()
# Out:
# (428, 13)
#   Vehicle_Make   Vehicle_Model Vehicle_Type Manufacturing_Origin  MPG_City  \
# 0        Acura             MDX          SUV                 Asia        17
# 1        Acura  RSX Type S 2dr        Sedan                 Asia        24
# 2        Acura         TSX 4dr        Sedan                 Asia        22
# 3        Acura          TL 4dr        Sedan                 Asia        20
# 4        Acura      3.5 RL 4dr        Sedan                 Asia        18
#
#    MPG_Hwy   MSRP  Invoice  Weight  Wheelbase DriveTrain  EngineSize  \
# 0       23  36945    33337    4451        106        All         3.5
# 1       31  23820    21761    2778        101      Front         2.0
# 2       29  26990    24647    3230        105      Front         2.4
# 3       28  33195    30299    3575        108      Front         3.2
# 4       24  43755    39014    3880        115      Front         3.5
#
#    Horsepower
# 0         265
# 1         200
# 2         200
# 3         270
# 4         225

# %%
df.dtypes
# Out:
# Vehicle_Make             object
# Vehicle_Model            object
# Vehicle_Type             object
# Manufacturing_Origin     object
# MPG_City                  int64
# MPG_Hwy                   int64
# MSRP                      int64
# Invoice                   int64
# Weight                    int64
# Wheelbase                 int64
# DriveTrain               object
# EngineSize              float64
# Horsepower                int64
# dtype: object

# %% [markdown]
# # Sorting by a Single Column

# %% [markdown]
# ### Sort Highest to Lowest

# %%
df.sort_values(by='MPG_City', ascending=False, inplace=True)

print(df.shape)
df.head()
# Out:
# (428, 13)
#     Vehicle_Make                           Vehicle_Model Vehicle_Type  \
# 150        Honda              Insight 2dr (gas/electric)       Hybrid
# 373       Toyota                Prius 4dr (gas/electric)       Hybrid
# 149        Honda  Civic Hybrid 4dr manual (gas/electric)       Hybrid
# 404   Volkswagen                       Jetta GLS TDI 4dr        Sedan
# 155        Honda                            Civic HX 2dr        Sedan
#
#     Manufacturing_Origin  MPG_City  MPG_Hwy   MSRP  Invoice  Weight  \
# 150                 Asia        60       66  19110    17911    1850
# 373                 Asia        59       51  20510    18926    2890
# 149                 Asia        46       51  20140    18451    2732
# 404               Europe        38       46  21055    19638    3003
# 155                 Asia        36       44  14170    12996    2500
#
#      Wheelbase DriveTrain  EngineSize  Horsepower
# 150         95      Front         2.0          73
# 373        106      Front         1.5         110
# 149        103      Front         1.4          93
# 404         99      Front         1.9         100
# 155        103      Front         1.7         117

# %% [markdown]
# ### Sort Lowest to Highest

# %%
df.sort_values(by='MPG_City', ascending=True, inplace=True)


print(df.shape)
df.head()
# Out:
# (428, 13)
#     Vehicle_Make      Vehicle_Model Vehicle_Type Manufacturing_Origin  \
# 166       Hummer                 H2          SUV                  USA
# 118         Ford  Excursion 6.8 XLT          SUV                  USA
# 216   Land Rover       Discovery SE          SUV               Europe
# 215   Land Rover    Range Rover HSE          SUV               Europe
# 412   Volkswagen    Phaeton W12 4dr        Sedan               Europe
#
#      MPG_City  MPG_Hwy   MSRP  Invoice  Weight  Wheelbase DriveTrain  \
# 166        10       12  49995    45815    6400        123        All
# 118        10       13  41475    36494    7190        137        All
# 216        12       16  39250    35777    4576        100        All
# 215        12       16  72250    65807    5379        113        All
# 412        12       19  75000    69130    5399        118      Front
#
#      EngineSize  Horsepower
# 166         6.0         316
# 118         6.8         310
# 216         4.6         217
# 215         4.4         282
# 412         6.0         420

# %% [markdown]
# # Sorting by Two Columns

# %% [markdown]
# ### Sort by Origin (Alphabetically) and MPG_City (Most to Least)

# %%
df.sort_values(by=['Manufacturing_Origin', 'MPG_City'], ascending=[True, False], inplace=True)

print(df.shape)
df.head()
# Out:
# (428, 13)
#     Vehicle_Make                           Vehicle_Model Vehicle_Type  \
# 150        Honda              Insight 2dr (gas/electric)       Hybrid
# 373       Toyota                Prius 4dr (gas/electric)       Hybrid
# 149        Honda  Civic Hybrid 4dr manual (gas/electric)       Hybrid
# 155        Honda                            Civic HX 2dr        Sedan
# 382       Toyota                         Echo 2dr manual        Sedan
#
#     Manufacturing_Origin  MPG_City  MPG_Hwy   MSRP  Invoice  Weight  \
# 150                 Asia        60       66  19110    17911    1850
# 373                 Asia        59       51  20510    18926    2890
# 149                 Asia        46       51  20140    18451    2732
# 155                 Asia        36       44  14170    12996    2500
# 382                 Asia        35       43  10760    10144    2035
#
#      Wheelbase DriveTrain  EngineSize  Horsepower
# 150         95      Front         2.0          73
# 373        106      Front         1.5         110
# 149        103      Front         1.4          93
# 155        103      Front         1.7         117
# 382         93      Front         1.5         108

# %% [markdown]
# ### Sort by Origin (Reverse Alphabetically) and MPG_City (Least to Most)

# %%
df.sort_values(by=['Manufacturing_Origin', 'MPG_City'], ascending=[False, True], inplace=True)

print(df.shape)
df.head()
# Out:
# (428, 13)
#     Vehicle_Make                 Vehicle_Model Vehicle_Type  \
# 166       Hummer                            H2          SUV
# 118         Ford             Excursion 6.8 XLT          SUV
# 114        Dodge  Viper SRT-10 convertible 2dr       Sports
# 87     Chevrolet                  Silverado SS        Truck
# 147          GMC                Sierra HD 2500        Truck
#
#     Manufacturing_Origin  MPG_City  MPG_Hwy   MSRP  Invoice  Weight  \
# 166                  USA        10       12  49995    45815    6400
# 118                  USA        10       13  41475    36494    7190
# 114                  USA        12       20  81795    74451    3410
# 87                   USA        13       17  40340    35399    4804
# 147                  USA        13       18  29322    25759    5440
#
#      Wheelbase DriveTrain  EngineSize  Horsepower
# 166        123        All         6.0         316
# 118        137        All         6.8         310
# 114         99       Rear         8.3         500
# 87         144        All         6.0         300
# 147        133        All         6.0         300

# %% [markdown]
# # Sorting by Three Columns

# %% [markdown]
# ### Sort by Origin (Alphabetically), Type (Alphabetically) and MPG_City (Most to Least)

# %%
df.sort_values(by=['Manufacturing_Origin', 'Vehicle_Type', 'MPG_City'], ascending=[True, True, False], inplace=True)

print(df.shape)
df.head(10)
# Out:
# (428, 13)
#     Vehicle_Make                           Vehicle_Model Vehicle_Type  \
# 150        Honda              Insight 2dr (gas/electric)       Hybrid
# 373       Toyota                Prius 4dr (gas/electric)       Hybrid
# 149        Honda  Civic Hybrid 4dr manual (gas/electric)       Hybrid
# 240        Mazda                          Tribute DX 2.0          SUV
# 378       Toyota                                    RAV4          SUV
# 288   Mitsubishi                            Outlander LS          SUV
# 153        Honda                              Element LX          SUV
# 152        Honda                                 CR-V LX          SUV
# 167      Hyundai                            Santa Fe GLS          SUV
# 366       Suzuki                               Vitara LX          SUV
#
#     Manufacturing_Origin  MPG_City  MPG_Hwy   MSRP  Invoice  Weight  \
# 150                 Asia        60       66  19110    17911    1850
# 373                 Asia        59       51  20510    18926    2890
# 149                 Asia        46       51  20140    18451    2732
# 240                 Asia        22       25  21087    19742    3091
# 378                 Asia        22       27  20290    18553    3119
# 288                 Asia        21       27  18892    17569    3240
# 153                 Asia        21       24  18690    17334    3468
# 152                 Asia        21       25  19860    18419    3258
# 167                 Asia        20       26  21589    20201    3549
# 366                 Asia        19       22  17163    16949    3020
#
#      Wheelbase DriveTrain  EngineSize  Horsepower
# 150         95      Front         2.0          73
# 373        106      Front         1.5         110
# 149        103      Front         1.4          93
# 240        103        All         2.0         130
# 378         98        All         2.4         161
# 288        103      Front         2.4         160
# 153        101        All         2.4         160
# 152        103        All         2.4         160
# 167        103      Front         2.7         173
# 366         98        All         2.5         165
