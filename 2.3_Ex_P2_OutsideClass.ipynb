# %% [markdown]
# # 2.3 Ex: Part 2 (Outside Class)
#
# - Data file:  **Sample - Superstore.xlsx**

# %%
import pandas as pd

# %% [markdown]
# ### Read the datafile File into a *pandas* Dataframe

# %%
df = pd.read_excel("Data/Sample - Superstore.xlsx", "Orders", skiprows=0)

print("2.3 Ex: Part 2. Reading Excel")
print(df.shape)
df.head()
# Out:
# 2.3 Ex: Part 2. Reading Excel
# (9994, 21)
# c:\Users\W10\anaconda3\envs\Cis340_Fall_2022\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#    Row ID        Order ID Order_Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2019-152156 2019-11-08 2019-11-11    Second Class    CG-12520
# 1       2  CA-2019-152156 2019-11-08 2019-11-11    Second Class    CG-12520
# 2       3  CA-2019-138688 2019-06-12 2019-06-16    Second Class    DV-13045
# 3       4  US-2018-108966 2018-10-11 2018-10-18  Standard Class    SO-20335
# 4       5  US-2018-108966 2018-10-11 2018-10-18  Standard Class    SO-20335
#
#      Customer Name Business_Segment Country/Region             City  ...  \
# 0      Claire Gute         Consumer  United States        Henderson  ...
# 1      Claire Gute         Consumer  United States        Henderson  ...
# ...

# %%
df.dtypes
# Out:
# Row ID                       int64
# Order ID                    object
# Order_Date          datetime64[ns]
# Ship Date           datetime64[ns]
# Ship Mode                   object
# Customer ID                 object
# Customer Name               object
# Business_Segment            object
# Country/Region              object
# City                        object
# State                       object
# Zipcode                    float64
# Region                      object
# Product_ID                  object
# Category                    object
# Subcategory                 object
# Product_Name                object
# Sales                      float64
# Quantity                     int64
# Discount                   float64
# Profit                     float64
# dtype: object

# %% [markdown]
# # Q2.1: Show the rows in North Carolina, Georgia and Virginia with Sales greater than $500

# %%
df['State'].unique()
# Out:
# array(['Kentucky', 'California', 'Florida', 'North Carolina',
#        'Washington', 'Texas', 'Wisconsin', 'Utah', 'Nebraska',
#        'Pennsylvania', 'Illinois', 'Minnesota', 'Michigan', 'Delaware',
#        'Indiana', 'New York', 'Arizona', 'Virginia', 'Tennessee',
#        'Alabama', 'South Carolina', 'Oregon', 'Colorado', 'Iowa', 'Ohio',
#        'Missouri', 'Oklahoma', 'New Mexico', 'Louisiana', 'Connecticut',
#        'New Jersey', 'Massachusetts', 'Georgia', 'Nevada', 'Rhode Island',
#        'Mississippi', 'Arkansas', 'Montana', 'New Hampshire', 'Maryland',
#        'District of Columbia', 'Kansas', 'Vermont', 'Maine',
#        'South Dakota', 'Idaho', 'North Dakota', 'Wyoming',
#        'West Virginia'], dtype=object)

# %%
selected_states = ['North Carolina', 'Georgia', 'Virginia' ]

# %%
df_Q1 = df.query("State in @selected_states and Sales > 500.0")

print("Q2.1: Show the rows in North Carolina, Georgia and Virginia with Sales greater than $500")
print(df_Q1.shape)
df_Q1
# Out:
# Q2.1: Show the rows in North Carolina, Georgia and Virginia with Sales greater than $500
# (81, 21)
#       Row ID        Order ID Order_Date  Ship Date       Ship Mode  \
# 359      360  CA-2020-155698 2020-03-08 2020-03-11     First Class
# 509      510  CA-2018-145352 2018-03-16 2018-03-22  Standard Class
# 683      684  US-2020-168116 2020-11-04 2020-11-04        Same Day
# 769      770  CA-2019-157245 2019-05-19 2019-05-24  Standard Class
# 792      793  CA-2019-105256 2019-05-20 2019-05-20        Same Day
# ...      ...             ...        ...        ...             ...
# 8964    8965  CA-2019-157280 2019-11-05 2019-11-07     First Class
# 9639    9640  CA-2018-116638 2018-01-28 2018-01-31    Second Class
# 9689    9690  US-2020-135986 2020-06-20 2020-06-27  Standard Class
# 9732    9733  CA-2017-114321 2017-08-20 2017-08-25  Standard Class
# 9734    9735  CA-2017-114321 2017-08-20 2017-08-25  Standard Class
#
# ...

# %%
df_Q1['State'].unique()
# Out:
# array(['Georgia', 'North Carolina', 'Virginia'], dtype=object)

# %%
df_Q1['Sales'].unique()
# Out:
# array([ 647.84 , 6354.95 , 7999.98 ,  641.96 , 1363.96 , 2715.93 ,
#         617.97 ,  619.95 , 2244.48 ,  540.048,  572.76 ,  695.7  ,
#        1441.3  , 1127.976, 1245.86 ,  595.38 ,  723.92 ,  826.11 ,
#         571.44 ,  675.12 , 1139.92 , 2690.97 , 1628.82 ,  959.968,
#        1633.188, 1267.65 ,  504.9  , 4164.05 ,  580.672,  579.95 ,
#        1202.94 ,  569.536,  523.764, 1359.96 ,  542.94 ,  978.84 ,
#        2624.985,  544.38 , 1599.92 ,  863.928, 1126.02 , 1263.3  ,
#        1781.682, 2275.5  , 1979.7  , 2999.95 , 1256.22 , 1049.93 ,
#         701.96 ,  945.036,  962.08 ,  627.168, 1059.12 , 1652.94 ,
#        1012.68 , 1350.12 ,  569.64 , 1196.86 ,  523.26 ,  591.32 ,
#        3499.93 , 1299.99 ,  872.94 ,  876.3  , 1871.88 , 1266.86 ,
#         675.06 , 2939.93 ,  630.024, 8749.95 , 1056.86 ,  704.76 ,
#        2104.55 , 1270.99 ,  942.784,  698.352,  756.8  , 4297.644,
#         503.96 ,  500.24 ,  896.99 ])
