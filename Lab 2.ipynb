# %% [markdown]
# # Lab 2

# %%
import pandas as pd

# %% [markdown]
# # Part 1: Read cars
# Read the CSV File into a *pandas* Dataframe  and display basic info about the new *pandas* Dataframe.
#
# - Filename:  **Cars.csv**
#  <!--  -->
# - **Demonstrates**:
#   - The number of Rows and Columns
#   - The first five rows of the Dataframe

# %%
df = pd.read_csv("Data/Cars.csv", skiprows=0)

print(df.shape)
df.head()
# Out:
# (428, 13)
#   Vehicle_Make   Vehicle_Model Vehicle_Type Manufacturing_Origin  MPG_City  \
# 0        Acura             MDX          SUV                 Asia        17
# 1        Acura  RSX Type S 2dr        Sedan                 Asia        24
# 2        Acura         TSX 4dr        Sedan                 Asia        22
# 3        Acura          TL 4dr        Sedan                 Asia        20
# 4        Acura      3.5 RL 4dr        Sedan                 Asia        18
#
#    MPG_Hwy   MSRP  Invoice  Weight  Wheelbase DriveTrain  EngineSize  \
# 0       23  36945    33337    4451        106        All         3.5
# 1       31  23820    21761    2778        101      Front         2.0
# 2       29  26990    24647    3230        105      Front         2.4
# 3       28  33195    30299    3575        108      Front         3.2
# 4       24  43755    39014    3880        115      Front         3.5
#
#    Horsepower
# 0         265
# 1         200
# 2         200
# 3         270
# ...

# %% [markdown]
# # Part 2: Read Sample - Superstore.xlx
# Read an Excel worksheet into a *pandas* Dataframe and display basic info about the new *pandas* Dataframe.
#
#
# - Data file:  **Sample - Superstore.xlsx**
# - Worksheet:   **Orders**
#
#
# - **Demonstrates**:
#   - The number of Rows and Columns
#   - The first five rows of the Dataframe

# %%
df = pd.read_excel("Data/Sample - Superstore.xlsx", "Orders", skiprows=0)

print(df.shape)
df.head()
# Out:
# Ex 2.2: Part 2
# (9994, 21)
# c:\Users\W10\anaconda3\envs\Cis340_Fall_2022\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#    Row ID        Order ID Order_Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2019-152156 2019-11-08 2019-11-11    Second Class    CG-12520
# 1       2  CA-2019-152156 2019-11-08 2019-11-11    Second Class    CG-12520
# 2       3  CA-2019-138688 2019-06-12 2019-06-16    Second Class    DV-13045
# 3       4  US-2018-108966 2018-10-11 2018-10-18  Standard Class    SO-20335
# 4       5  US-2018-108966 2018-10-11 2018-10-18  Standard Class    SO-20335
#
#      Customer Name Business_Segment Country/Region             City  ...  \
# 0      Claire Gute         Consumer  United States        Henderson  ...
# 1      Claire Gute         Consumer  United States        Henderson  ...
# ...

# %% [markdown]
# # Part 3: Read 2019_pep_char_All_County_HISP-SEX.csv
# Read the CSV File into a *pandas* Dataframe  and display basic info about the new *pandas* Dataframe.
#
# - Filename:  **2019_pep_char_All_County_HISP-SEX.csv**
#
# - **Demonstrates**:
#   - The number of Rows and Columns
#   - The first five rows of the Dataframe

# %%
df = pd.read_csv("Data/2019_pep_char_All_County_HISP-SEX.csv", skiprows=0, dtype={'county':str})

print(df.shape)
df.head()
# Out:
# (28512, 6)
#                         NAME  HISP  SEX    POP  state county
# Coahoma County   Mississippi     0    0  22124     28    027
# Coahoma County   Mississippi     1    0  21757     28    027
# Coahoma County   Mississippi     2    0    367     28    027
# Coahoma County   Mississippi     0    1  10254     28    027
# Coahoma County   Mississippi     1    1  10059     28    027

# %% [markdown]
# # Part 4: Internet Users Worldwide
# Read an Excel worksheet into a *pandas* Dataframe and display basic info about the new *pandas* Dataframe.
#
#
# - Data file:  **Internet_users_worldwide.xlsx**
# - Worksheet:   **Data**
#
#
# - **Demonstrates**:
#   - The number of Rows and Columns
#   - The first five rows of the Dataframe

# %%
df = pd.read_excel("Data/Internet_users_worldwide.xlsx", "Data", skiprows=3)

print(df.shape)
df.head()
# Out:
# (266, 66)
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                      Indicator Name  Indicator Code  1960  \
# 0  Individuals using the Internet (% of population)  IT.NET.USER.ZS   NaN
# 1  Individuals using the Internet (% of population)  IT.NET.USER.ZS   NaN
# 2  Individuals using the Internet (% of population)  IT.NET.USER.ZS   NaN
# 3  Individuals using the Internet (% of population)  IT.NET.USER.ZS   NaN
# 4  Individuals using the Internet (% of population)  IT.NET.USER.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...       2012       2013       2014  \
# 0   NaN   NaN   NaN   NaN   NaN  ...  74.000000  78.900000  83.780000
# 1   NaN   NaN   NaN   NaN   NaN  ...   8.575522  10.189313  12.304789
# ...

# %% [markdown]
# # Part 5: Agricultural machinery
# Read an Excel worksheet into a *pandas* Dataframe and display basic info about the new *pandas* Dataframe.
#
#
# - Data file:  **Agricultural_machinery.xlsx**
# - Worksheet:   **Data**
#
#
# - **Demonstrates**:
#   - The number of Rows and Columns
#   - The first five rows of the Dataframe

# %%
df = pd.read_excel("Data/Agricultural_machinery.xlsx", "Data", skiprows=3)

print(df.shape)
df.head()
# Out:
# (266, 66)
#                   Country Name Country Code                    Indicator Name  \
# 0                        Aruba          ABW  Agricultural machinery, tractors
# 1  Africa Eastern and Southern          AFE  Agricultural machinery, tractors
# 2                  Afghanistan          AFG  Agricultural machinery, tractors
# 3   Africa Western and Central          AFW  Agricultural machinery, tractors
# 4                       Angola          AGO  Agricultural machinery, tractors
#
#    Indicator Code  1960      1961      1962      1963      1964      1965  \
# 0  AG.AGR.TRAC.NO   NaN       NaN       NaN       NaN       NaN       NaN
# 1  AG.AGR.TRAC.NO   NaN  169776.0  176648.0  180067.0  185072.0  191771.0
# 2  AG.AGR.TRAC.NO   NaN     120.0     150.0     200.0     200.0     300.0
# 3  AG.AGR.TRAC.NO   NaN    2733.0    3772.0    4577.0    5404.0    6364.0
# 4  AG.AGR.TRAC.NO   NaN     800.0    1645.0    2000.0    2817.0    3000.0
#
# ...
