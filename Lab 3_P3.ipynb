# %% [markdown]
# # Lab 3

# %%
import pandas as pd

# %% [markdown]
# # Part 3: Read xlsx

# %%
df = pd.read_excel("Data/Agricultural_machinery.xlsx", 'Data', skiprows=3)

print(df.shape)
df.head()
# Out:
# (266, 66)
#                   Country Name Country Code                    Indicator Name  \
# 0                        Aruba          ABW  Agricultural machinery, tractors
# 1  Africa Eastern and Southern          AFE  Agricultural machinery, tractors
# 2                  Afghanistan          AFG  Agricultural machinery, tractors
# 3   Africa Western and Central          AFW  Agricultural machinery, tractors
# 4                       Angola          AGO  Agricultural machinery, tractors
#
#    Indicator Code  1960      1961      1962      1963      1964      1965  \
# 0  AG.AGR.TRAC.NO   NaN       NaN       NaN       NaN       NaN       NaN
# 1  AG.AGR.TRAC.NO   NaN  169776.0  176648.0  180067.0  185072.0  191771.0
# 2  AG.AGR.TRAC.NO   NaN     120.0     150.0     200.0     200.0     300.0
# 3  AG.AGR.TRAC.NO   NaN    2733.0    3772.0    4577.0    5404.0    6364.0
# 4  AG.AGR.TRAC.NO   NaN     800.0    1645.0    2000.0    2817.0    3000.0
#
# ...

# %%
df.dtypes
# Out:
# Country Name       object
# Country Code       object
# Indicator Name     object
# Indicator Code     object
# 1960              float64
#                    ...
# 2017              float64
# 2018              float64
# 2019              float64
# 2020              float64
# 2021              float64
# Length: 66, dtype: object

# %% [markdown]
# # Q3.1:  In 1965, what were the Top 10 Countries for agricultural machinery?

# %%
df_Q1 = df.sort_values(by='1965', ascending=False)

print("Q3.1:  In 1965, what were the Top 10 Countries for agricultural machinery? ")

df_TopN = df_Q1.iloc[ : 10]
print(df_TopN.shape)
df_TopN
# Out:
# Q3.1:  In 1965, what were the Top 10 Countries for agricultural machinery?
# (10, 66)
#                   Country Name Country Code                    Indicator Name  \
# 259                      World          WLD  Agricultural machinery, tractors
# 181               OECD members          OED  Agricultural machinery, tractors
# 95                 High income          HIC  Agricultural machinery, tractors
# 198  Post-demographic dividend          PST  Agricultural machinery, tractors
# 170              North America          NAC  Agricultural machinery, tractors
# 251              United States          USA  Agricultural machinery, tractors
# 73              European Union          EUU  Agricultural machinery, tractors
# 68                   Euro area          EMU  Agricultural machinery, tractors
# 55                     Germany          DEU  Agricultural machinery, tractors
# 103           IDA & IBRD total          IBT  Agricultural machinery, tractors
#
# ...
