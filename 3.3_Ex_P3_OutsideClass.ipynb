# %% [markdown]
# # Ex 3.3: Part 3 (Outside Class)

# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# ### Read Data into dataframe

# %%
df = pd.read_excel("Data/SP500.xls", "Slightly Cleaned", skiprows=0)

print(df.shape)
df.head()
# Out:
# (1305, 2)
#   observation_date    SP500
# 0       2017-09-27  2507.04
# 1       2017-09-28  2510.06
# 2       2017-09-29  2519.36
# 3       2017-10-02  2529.12
# 4       2017-10-03  2534.58

# %%
fig = px.line(df, 
              x='observation_date', 
              y='SP500',
              template='plotly_dark',
              title='S&P 500')
fig.show()
