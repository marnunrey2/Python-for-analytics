# %% [markdown]
# # Ex 7.3: Part I (In Class)
#
# - API key: 9ae52fc6c0a4433e5e9a88ff5c633c2d

# %%
import pandas as pd
import plotly.express as px

import json
import requests
import pprint

# %% [markdown]
# **API Call Steps:**
# 1. Build the Request URL
# 2. Use the requests library to make the API call
# 3. Figure out what *key* (if any) to use to carve out the data we want from the returned data
# 4. Get the retrieved data into a Dataframe

# %% [markdown]
# # 1. Build the Request URL

# %% [markdown]
# ### Choose Desired Data Series
# - This may be the only thing you have to change!

# %%
series = "?series_id=UNRATE"

# %% [markdown]
# ### Base URL

# %%
base_url = "https://api.stlouisfed.org/fred//series/observations"

# %% [markdown]
# ### API Key
# - **You will have to copy your FRED API key between the quotes below for the API Call to work!**

# %%
api_key = "&api_key=9ae52fc6c0a4433e5e9a88ff5c633c2d"

# %%
### Returned data type
returned_data_type = "&file_type=json"

# %% [markdown]
# # Put them all together and test URL!

# %%
request_url = base_url + series + api_key + returned_data_type
#additional_routing

print("request_url = ", request_url)
# Out:
# request_url =  https://api.stlouisfed.org/fred//series/observations?series_id=UNRATE&api_key=9ae52fc6c0a4433e5e9a88ff5c633c2d&file_type=json

# %% [markdown]
# # 2. Use *requests* library to make the API call

# %%
# Make API Call
r = requests.get(request_url)

api_results = r.json()

# %% [markdown]
# ### 3. Figure out what Key (if any) to use to carve out the data we want from the returned data

# %%
api_results
# Out:
# {'realtime_start': '2022-11-14',
#  'realtime_end': '2022-11-14',
#  'observation_start': '1600-01-01',
#  'observation_end': '9999-12-31',
#  'units': 'lin',
#  'output_type': 1,
#  'file_type': 'json',
#  'order_by': 'observation_date',
#  'sort_order': 'asc',
#  'count': 898,
#  'offset': 0,
#  'limit': 100000,
#  'observations': [{'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1948-01-01',
#    'value': '3.4'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1948-02-01',
#    'value': '3.8'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1948-03-01',
#    'value': '4.0'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1948-04-01',
#    'value': '3.9'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1948-05-01',
#    'value': '3.5'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1948-06-01',
#    'value': '3.6'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1948-07-01',
#    'value': '3.6'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1948-08-01',
#    'value': '3.9'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1948-09-01',
#    'value': '3.8'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1948-10-01',
#    'value': '3.7'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1948-11-01',
#    'value': '3.8'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1948-12-01',
#    'value': '4.0'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1949-01-01',
#    'value': '4.3'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1949-02-01',
#    'value': '4.7'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1949-03-01',
#    'value': '5.0'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1949-04-01',
#    'value': '5.3'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1949-05-01',
#    'value': '6.1'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1949-06-01',
#    'value': '6.2'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1949-07-01',
#    'value': '6.7'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1949-08-01',
#    'value': '6.8'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1949-09-01',
#    'value': '6.6'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1949-10-01',
#    'value': '7.9'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1949-11-01',
#    'value': '6.4'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1949-12-01',
#    'value': '6.6'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1950-01-01',
#    'value': '6.5'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1950-02-01',
#    'value': '6.4'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1950-03-01',
#    'value': '6.3'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1950-04-01',
#    'value': '5.8'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1950-05-01',
#    'value': '5.5'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1950-06-01',
#    'value': '5.4'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1950-07-01',
#    'value': '5.0'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1950-08-01',
#    'value': '4.5'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1950-09-01',
#    'value': '4.4'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1950-10-01',
#    'value': '4.2'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1950-11-01',
#    'value': '4.2'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1950-12-01',
#    'value': '4.3'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1951-01-01',
#    'value': '3.7'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1951-02-01',
#    'value': '3.4'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1951-03-01',
#    'value': '3.4'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1951-04-01',
#    'value': '3.1'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1951-05-01',
#    'value': '3.0'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1951-06-01',
#    'value': '3.2'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1951-07-01',
#    'value': '3.1'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1951-08-01',
#    'value': '3.1'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1951-09-01',
#    'value': '3.3'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1951-10-01',
#    'value': '3.5'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1951-11-01',
#    'value': '3.5'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1951-12-01',
#    'value': '3.1'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1952-01-01',
#    'value': '3.2'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1952-02-01',
#    'value': '3.1'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1952-03-01',
#    'value': '2.9'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1952-04-01',
#    'value': '2.9'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1952-05-01',
#    'value': '3.0'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1952-06-01',
#    'value': '3.0'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1952-07-01',
#    'value': '3.2'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1952-08-01',
#    'value': '3.4'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1952-09-01',
#    'value': '3.1'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1952-10-01',
#    'value': '3.0'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1952-11-01',
#    'value': '2.8'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1952-12-01',
#    'value': '2.7'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1953-01-01',
#    'value': '2.9'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1953-02-01',
#    'value': '2.6'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1953-03-01',
#    'value': '2.6'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1953-04-01',
#    'value': '2.7'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1953-05-01',
#    'value': '2.5'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1953-06-01',
#    'value': '2.5'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1953-07-01',
#    'value': '2.6'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1953-08-01',
#    'value': '2.7'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1953-09-01',
#    'value': '2.9'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1953-10-01',
#    'value': '3.1'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1953-11-01',
#    'value': '3.5'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1953-12-01',
#    'value': '4.5'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1954-01-01',
#    'value': '4.9'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1954-02-01',
#    'value': '5.2'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1954-03-01',
#    'value': '5.7'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1954-04-01',
#    'value': '5.9'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1954-05-01',
#    'value': '5.9'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1954-06-01',
#    'value': '5.6'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1954-07-01',
#    'value': '5.8'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1954-08-01',
#    'value': '6.0'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1954
01',
#    'value': '6.9'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1977-08-01',
#    'value': '7.0'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1977-09-01',
#    'value': '6.8'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1977-10-01',
#    'value': '6.8'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1977-11-01',
#    'value': '6.8'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1977-12-01',
#    'value': '6.4'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1978-01-01',
#    'value': '6.4'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1978-02-01',
#    'value': '6.3'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1978-03-01',
#    'value': '6.3'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1978-04-01',
#    'value': '6.1'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1978-05-01',
#    'value': '6.0'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1978-06-01',
#    'value': '5.9'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1978-07-01',
#    'value': '6.2'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1978-08-01',
#    'value': '5.9'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1978-09-01',
#    'value': '6.0'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1978-10-01',
#    'value': '5.8'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1978-11-01',
#    'value': '5.9'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1978-12-01',
#    'value': '6.0'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1979-01-01',
#    'value': '5.9'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1979-02-01',
#    'value': '5.9'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1979-03-01',
#    'value': '5.8'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1979-04-01',
#    'value': '5.8'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1979-05-01',
#    'value': '5.6'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1979-06-01',
#    'value': '5.7'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1979-07-01',
#    'value': '5.7'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1979-08-01',
#    'value': '6.0'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1979-09-01',
#    'value': '5.9'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1979-10-01',
#    'value': '6.0'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1979-11-01',
#    'value': '5.9'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1979-12-01',
#    'value': '6.0'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1980-01-01',
#    'value': '6.3'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1980-02-01',
#    'value': '6.3'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1980-03-01',
#    'value': '6.3'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1980-04-01',
#    'value': '6.9'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1980-05-01',
#    'value': '7.5'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1980-06-01',
#    'value': '7.6'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1980-07-01',
#    'value': '7.8'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1980-08-01',
#    'value': '7.7'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1980-09-01',
#    'value': '7.5'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1980-10-01',
#    'value': '7.5'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1980-11-01',
#    'value': '7.5'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1980-12-01',
#    'value': '7.2'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1981-01-01',
#    'value': '7.5'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1981-02-01',
#    'value': '7.4'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1981-03-01',
#    'value': '7.4'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1981-04-01',
#    'value': '7.2'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1981-05-01',
#    'value': '7.5'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1981-06-01',
#    'value': '7.5'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1981-07-01',
#    'value': '7.2'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1981-08-01',
#    'value': '7.4'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1981-09-01',
#    'value': '7.6'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1981-10-01',
#    'value': '7.9'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1981-11-01',
#    'value': '8.3'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1981-12-01',
#    'value': '8.5'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1982-01-01',
#    'value': '8.6'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1982-02-01',
#    'value': '8.9'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1982-03-01',
#    'value': '9.0'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1982-04-01',
#    'value': '9.3'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1982-05-01',
#    'value': '9.4'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1982-06-01',
#    'value': '9.6'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1982-07-01',
#    'value': '9.8'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1982-08-01',
#    'value': '9.8'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1982-09-01',
#    'value': '10.1'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1982-10-01',
#    'value': '10.4'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1982-11-01',
#    'value': '10.8'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1982-12-01',
#    'value': '10.8'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1983-01-01',
#    'value': '10.4'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '1983-02-01',
# ...
#    'date': '2011-01-01',
#    'value': '9.1'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2011-02-01',
#    'value': '9.0'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2011-03-01',
#    'value': '9.0'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2011-04-01',
#    'value': '9.1'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2011-05-01',
#    'value': '9.0'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2011-06-01',
#    'value': '9.1'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2011-07-01',
#    'value': '9.0'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2011-08-01',
#    'value': '9.0'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2011-09-01',
#    'value': '9.0'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2011-10-01',
#    'value': '8.8'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2011-11-01',
#    'value': '8.6'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2011-12-01',
#    'value': '8.5'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2012-01-01',
#    'value': '8.3'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2012-02-01',
#    'value': '8.3'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2012-03-01',
#    'value': '8.2'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2012-04-01',
#    'value': '8.2'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2012-05-01',
#    'value': '8.2'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2012-06-01',
#    'value': '8.2'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2012-07-01',
#    'value': '8.2'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2012-08-01',
#    'value': '8.1'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2012-09-01',
#    'value': '7.8'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2012-10-01',
#    'value': '7.8'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2012-11-01',
#    'value': '7.7'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2012-12-01',
#    'value': '7.9'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2013-01-01',
#    'value': '8.0'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2013-02-01',
#    'value': '7.7'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2013-03-01',
#    'value': '7.5'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2013-04-01',
#    'value': '7.6'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2013-05-01',
#    'value': '7.5'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2013-06-01',
#    'value': '7.5'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2013-07-01',
#    'value': '7.3'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2013-08-01',
#    'value': '7.2'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2013-09-01',
#    'value': '7.2'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2013-10-01',
#    'value': '7.2'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2013-11-01',
#    'value': '6.9'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2013-12-01',
#    'value': '6.7'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2014-01-01',
#    'value': '6.6'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2014-02-01',
#    'value': '6.7'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2014-03-01',
#    'value': '6.7'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2014-04-01',
#    'value': '6.2'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2014-05-01',
#    'value': '6.3'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2014-06-01',
#    'value': '6.1'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2014-07-01',
#    'value': '6.2'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2014-08-01',
#    'value': '6.1'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2014-09-01',
#    'value': '5.9'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2014-10-01',
#    'value': '5.7'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2014-11-01',
#    'value': '5.8'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2014-12-01',
#    'value': '5.6'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2015-01-01',
#    'value': '5.7'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2015-02-01',
#    'value': '5.5'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2015-03-01',
#    'value': '5.4'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2015-04-01',
#    'value': '5.4'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2015-05-01',
#    'value': '5.6'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2015-06-01',
#    'value': '5.3'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2015-07-01',
#    'value': '5.2'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2015-08-01',
#    'value': '5.1'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2015-09-01',
#    'value': '5.0'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2015-10-01',
#    'value': '5.0'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2015-11-01',
#    'value': '5.1'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2015-12-01',
#    'value': '5.0'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2016-01-01',
#    'value': '4.8'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2016-02-01',
#    'value': '4.9'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2016-03-01',
#    'value': '5.0'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2016-04-01',
#    'value': '5.1'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2016-05-01',
#    'value': '4.8'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2016-06-01',
#    'value': '4.9'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2016-07-01',
#    'value': '4.8'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2016-08-01',
#    'value': '4.9'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2016-09-01',
#    'value': '5.0'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2016-10-01',
#    'value': '4.9'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2016-11-01',
#    'value': '4.7'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2016-12-01',
#    'value': '4.7'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2017-01-01',
#    'value': '4.7'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2017-02-01',
#    'value': '4.6'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2017-03-01',
#    'value': '4.4'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2017-04-01',
#    'value': '4.4'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2017-05-01',
#    'value': '4.4'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2017-06-01',
#    'value': '4.3'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2017-07-01',
#    'value': '4.3'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2017-08-01',
#    'value': '4.4'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2017-09-01',
#    'value': '4.3'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2017-10-01',
#    'value': '4.2'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2017-11-01',
#    'value': '4.2'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2017-12-01',
#    'value': '4.1'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2018-01-01',
#    'value': '4.0'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2018-02-01',
#    'value': '4.1'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2018-03-01',
#    'value': '4.0'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2018-04-01',
#    'value': '4.0'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2018-05-01',
#    'value': '3.8'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2018-06-01',
#    'value': '4.0'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2018-07-01',
#    'value': '3.8'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2018-08-01',
#    'value': '3.8'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2018-09-01',
#    'value': '3.7'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2018-10-01',
#    'value': '3.8'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2018-11-01',
#    'value': '3.8'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2018-12-01',
#    'value': '3.9'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2019-01-01',
#    'value': '4.0'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2019-02-01',
#    'value': '3.8'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2019-03-01',
#    'value': '3.8'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2019-04-01',
#    'value': '3.6'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2019-05-01',
#    'value': '3.6'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2019-06-01',
#    'value': '3.6'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2019-07-01',
#    'value': '3.7'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2019-08-01',
#    'value': '3.7'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2019-09-01',
#    'value': '3.5'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2019-10-01',
#    'value': '3.6'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2019-11-01',
#    'value': '3.6'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2019-12-01',
#    'value': '3.6'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2020-01-01',
#    'value': '3.5'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2020-02-01',
#    'value': '3.5'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2020-03-01',
#    'value': '4.4'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2020-04-01',
#    'value': '14.7'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2020-05-01',
#    'value': '13.2'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2020-06-01',
#    'value': '11.0'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2020-07-01',
#    'value': '10.2'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2020-08-01',
#    'value': '8.4'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2020-09-01',
#    'value': '7.9'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2020-10-01',
#    'value': '6.9'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2020-11-01',
#    'value': '6.7'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2020-12-01',
#    'value': '6.7'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2021-01-01',
#    'value': '6.4'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2021-02-01',
#    'value': '6.2'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2021-03-01',
#    'value': '6.0'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2021-04-01',
#    'value': '6.0'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2021-05-01',
#    'value': '5.8'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2021-06-01',
#    'value': '5.9'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2021-07-01',
#    'value': '5.4'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2021-08-01',
#    'value': '5.2'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2021-09-01',
#    'value': '4.7'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2021-10-01',
#    'value': '4.6'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2021-11-01',
#    'value': '4.2'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2021-12-01',
#    'value': '3.9'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2022-01-01',
#    'value': '4.0'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2022-02-01',
#    'value': '3.8'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2022-03-01',
#    'value': '3.6'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2022-04-01',
#    'value': '3.6'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2022-05-01',
#    'value': '3.6'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2022-06-01',
#    'value': '3.6'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2022-07-01',
#    'value': '3.5'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2022-08-01',
#    'value': '3.7'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2022-09-01',
#    'value': '3.5'},
#   {'realtime_start': '2022-11-14',
#    'realtime_end': '2022-11-14',
#    'date': '2022-10-01',
#    'value': '3.7'}]}

# %%
type(api_results)
# Out:
# dict

# %% [markdown]
# # 4. Get the data into a Dataframe
# - If it doesn't have multiple levels of data, use:   **DataFrame.from_dict()**
# - If it does have multiple levels of data, use **json_normalize()**

# %%
df = pd.DataFrame(api_results['observations'])

print(df.shape)
df.head()
# Out:
# (898, 4)
#   realtime_start realtime_end        date value
# 0     2022-11-14   2022-11-14  1948-01-01   3.4
# 1     2022-11-14   2022-11-14  1948-02-01   3.8
# 2     2022-11-14   2022-11-14  1948-03-01   4.0
# 3     2022-11-14   2022-11-14  1948-04-01   3.9
# 4     2022-11-14   2022-11-14  1948-05-01   3.5

# %% [markdown]
# # Clean data

# %% [markdown]
# ### Change data types (as needed)

# %%
df.dtypes
# Out:
# realtime_start    object
# realtime_end      object
# date              object
# value             object
# dtype: object

# %%
df['date'] = pd.to_datetime(df['date'])
df['value'] = pd.to_numeric(df['value'])

# %%
df.dtypes
# Out:
# realtime_start            object
# realtime_end              object
# date              datetime64[ns]
# value                    float64
# dtype: object

# %%
df['value'] = df['value']/100

# %%
print(df.shape)
df.head()
# Out:
# (898, 4)
#   realtime_start realtime_end       date  value
# 0     2022-11-14   2022-11-14 1948-01-01  0.034
# 1     2022-11-14   2022-11-14 1948-02-01  0.038
# 2     2022-11-14   2022-11-14 1948-03-01  0.040
# 3     2022-11-14   2022-11-14 1948-04-01  0.039
# 4     2022-11-14   2022-11-14 1948-05-01  0.035

# %% [markdown]
# # Filter

# %%
df_Q1 = df.query("date >= '2019-01-01'")
print(df_Q1.shape)
df_Q1.head()
# Out:
# (46, 4)
#     realtime_start realtime_end       date  value
# 852     2022-11-14   2022-11-14 2019-01-01  0.040
# 853     2022-11-14   2022-11-14 2019-02-01  0.038
# 854     2022-11-14   2022-11-14 2019-03-01  0.038
# 855     2022-11-14   2022-11-14 2019-04-01  0.036
# 856     2022-11-14   2022-11-14 2019-05-01  0.036

# %% [markdown]
# # Plot

# %%
fig = px.line(df_Q1,              
             x='date', 
             y='value',
             template='xgridoff',
             title='Part 1: Civilian Unemployment Rate (UNRATE) - 2019 Onward')


fig.show()
