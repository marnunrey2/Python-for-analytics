# %% [markdown]
# # Demo 4.1 - Part 1:  Screenscraping with pandas
#
# - **Skills Demonstrated:**
#   1. Screenscraping with *read_html()*
#
#
# - Web page with data: https://www.infoplease.com/us/states/state-population-by-rank
#
#
#
# - **Key Steps:**
#   1. Grab HTML Table data from web page
#     1. Each HTML Table of data will be stored as an item in the *tables* List
#   2. Choose the table of data (from the *tables* List) you want
#   3. Create a pandas dataframe from the chosen list item of data
#
#
# - **References:**
#   - [Quick Tip: The easiest way to grab data out of a web page in Python](https://medium.com/@ageitgey/quick-tip-the-easiest-way-to-grab-data-out-of-a-web-page-in-python-7153cecfca58)
#   - [Reading HTML Tables with pandas](https://pbpython.com/pandas-html-table.html)

# %%
import pandas as pd

# %% [markdown]
# # 1. Grab table(s) from web page
# - Each HTML table of data 0n the web page will be one item our the python List *tables*

# %%
tables = pd.read_html('https://www.infoplease.com/us/states/state-population-by-rank')

tables
# Out:
# [    Rank           State  2020 Census Percent of Total
#  0    1.0      California     39538223           11.91%
#  1    2.0           Texas     29145505            8.74%
#  2    3.0         Florida     21538187            6.47%
#  3    4.0        New York     20201249            5.86%
#  4    5.0    Pennsylvania     13002700            3.86%
#  5    6.0        Illinois     12801989            3.82%
#  6    7.0            Ohio     11799448            3.52%
#  7    8.0         Georgia     10711908            3.20%
#  8    9.0  North Carolina     10439388            3.16%
#  9   10.0        Michigan     10077331            3.01%
#  10  11.0      New Jersey      9288994            2.68%
#  11  12.0        Virginia      8631393            2.57%
#  12  13.0      Washington      7705281            2.29%
#  13  14.0         Arizona      7151502            2.19%
#  14  15.0   Massachusetts      7029917            2.09%
#  15  16.0       Tennessee      6910840            2.06%
#  16  17.0         Indiana      6785528            2.03%
#  17  18.0        Maryland      6177224            1.85%
#  18  19.0        Missouri      6154913            1.82%
#  19  20.0       Wisconsin      5893718            1.75%
#  20  21.0        Colorado      5773714            1.74%
#  21  22.0       Minnesota      5706494            1.70%
#  22  23.0  South Carolina      5118425            1.55%
#  23  24.0         Alabama      5024279            1.48%
#  24  25.0       Louisiana      4657757            1.40%
#  25  26.0        Kentucky      4505836            1.35%
#  26  27.0          Oregon      4237256            1.27%
#  27  28.0        Oklahoma      3959353            1.19%
#  28  29.0     Connecticut      3605944            1.07%
#  29  30.0            Utah      3205958            0.97%
#  30  31.0            Iowa      3271616            0.95%
#  31  32.0          Nevada      3104614            0.93%
#  32  33.0        Arkansas      3011524            0.91%
#  33  34.0     Mississippi      2961279            0.90%
#  34  35.0          Kansas      2937880            0.88%
#  35  36.0      New Mexico      2117522            0.63%
#  36  37.0        Nebraska      1961504            0.58%
#  37  38.0           Idaho      1839106            0.54%
#  38  39.0   West Virginia      1793716            0.54%
#  39  40.0          Hawaii      1455271            0.43%
#  40  41.0   New Hampshire      1377529            0.41%
#  41  42.0           Maine      1362359            0.41%
#  42  43.0    Rhode Island      1097379            0.32%
#  43  44.0         Montana      1084225            0.32%
#  44  45.0        Delaware       989948            0.29%
#  45  46.0    South Dakota       886667            0.27%
#  46  47.0    North Dakota       779094            0.23%
#  47  48.0          Alaska       733391            0.22%
#  48  49.0              DC       689545            0.21%
#  49  50.0         Vermont       643077            0.19%
#  50  51.0         Wyoming       576851            0.17%
#  51   NaN      Total U.S.    331449281              NaN]

# %%
type(tables)
# Out:
# list

# %% [markdown]
# # 2. Choose the table of data (from the table List) you want

# %%
print("Number of Tables of Data in tables List:  ", len(tables))
# Out:
# Number of Tables of Data in tables List:   1

# %%
tables[0]
#tables[1]
#tables[2]
# Out:
#     Rank           State  2020 Census Percent of Total
# 0    1.0      California     39538223           11.91%
# 1    2.0           Texas     29145505            8.74%
# 2    3.0         Florida     21538187            6.47%
# 3    4.0        New York     20201249            5.86%
# 4    5.0    Pennsylvania     13002700            3.86%
# 5    6.0        Illinois     12801989            3.82%
# 6    7.0            Ohio     11799448            3.52%
# 7    8.0         Georgia     10711908            3.20%
# 8    9.0  North Carolina     10439388            3.16%
# 9   10.0        Michigan     10077331            3.01%
# 10  11.0      New Jersey      9288994            2.68%
# 11  12.0        Virginia      8631393            2.57%
# 12  13.0      Washington      7705281            2.29%
# 13  14.0         Arizona      7151502            2.19%
# 14  15.0   Massachusetts      7029917            2.09%
# 15  16.0       Tennessee      6910840            2.06%
# 16  17.0         Indiana      6785528            2.03%
# 17  18.0        Maryland      6177224            1.85%
# 18  19.0        Missouri      6154913            1.82%
# 19  20.0       Wisconsin      5893718            1.75%
# 20  21.0        Colorado      5773714            1.74%
# 21  22.0       Minnesota      5706494            1.70%
# 22  23.0  South Carolina      5118425            1.55%
# 23  24.0         Alabama      5024279            1.48%
# 24  25.0       Louisiana      4657757            1.40%
# 25  26.0        Kentucky      4505836            1.35%
# 26  27.0          Oregon      4237256            1.27%
# 27  28.0        Oklahoma      3959353            1.19%
# 28  29.0     Connecticut      3605944            1.07%
# 29  30.0            Utah      3205958            0.97%
# 30  31.0            Iowa      3271616            0.95%
# 31  32.0          Nevada      3104614            0.93%
# 32  33.0        Arkansas      3011524            0.91%
# 33  34.0     Mississippi      2961279            0.90%
# 34  35.0          Kansas      2937880            0.88%
# 35  36.0      New Mexico      2117522            0.63%
# 36  37.0        Nebraska      1961504            0.58%
# 37  38.0           Idaho      1839106            0.54%
# 38  39.0   West Virginia      1793716            0.54%
# 39  40.0          Hawaii      1455271            0.43%
# 40  41.0   New Hampshire      1377529            0.41%
# 41  42.0           Maine      1362359            0.41%
# 42  43.0    Rhode Island      1097379            0.32%
# 43  44.0         Montana      1084225            0.32%
# 44  45.0        Delaware       989948            0.29%
# 45  46.0    South Dakota       886667            0.27%
# 46  47.0    North Dakota       779094            0.23%
# 47  48.0          Alaska       733391            0.22%
# 48  49.0              DC       689545            0.21%
# 49  50.0         Vermont       643077            0.19%
# 50  51.0         Wyoming       576851            0.17%
# 51   NaN      Total U.S.    331449281              NaN

# %% [markdown]
# # 3. Create a pandas dataframe from the chosen list item of data

# %%
df = pd.DataFrame(tables[0])  

print(df.shape)
df.head()
# Out:
# (52, 4)
#    Rank         State  2020 Census Percent of Total
# 0   1.0    California     39538223           11.91%
# 1   2.0         Texas     29145505            8.74%
# 2   3.0       Florida     21538187            6.47%
# 3   4.0      New York     20201249            5.86%
# 4   5.0  Pennsylvania     13002700            3.86%

# %%
df.dtypes
# Out:
# Rank                float64
# State                object
# 2020 Census           int64
# Percent of Total     object
# dtype: object

# %% [markdown]
# # Optional:  Save the Dataframe as a CSV file

# %%
csv_file_to_create = "5.1_Demo_P1_StatePop.csv"

filename_with_path = "Data/" + csv_file_to_create
df.to_csv(filename_with_path, index=False)
